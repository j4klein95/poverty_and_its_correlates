# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet

from sklearn.metrics import mean_squared_error, r2_score
from pandas.tools.plotting import scatter_matrix

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
df = pd.read_csv("../csv/city_pov_2016_mn.csv")

# %%
df1 = pd.read_csv("../csv/main.csv")

# %%
corr_matrix = df.corr()
corr_matrix['Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people'].sort_values(ascending=False)
# Out:
# Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people                                              1.000000
# Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All families                                            0.924819
# Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - Families with female householder, no husband present    0.800453
# STROKE_AdjPrev                                                                                                                                                     0.795921
# Percent; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - With Food Stamp/SNAP benefits in the past 12 months                                            0.776293
# %onFoodStamps                                                                                                                                                      0.776293
# CHD_AdjPrev                                                                                                                                                        0.764488
# PHLTH_AdjPrev                                                                                                                                                      0.748284
# MHLTH_CrudePrev                                                                                                                                                    0.746496
# MHLTH_AdjPrev                                                                                                                                                      0.726647
# OBESITY_AdjPrev                                                                                                                                                    0.724492
# COPD_AdjPrev                                                                                                                                                       0.723577
# DIABETES_AdjPrev.1                                                                                                                                                 0.722793
# DIABETES_AdjPrev                                                                                                                                                   0.722793
# TEETHLOST_CrudePrev                                                                                                                                                0.720761
# % of pop 15+ not married                                                                                                                                           0.718928
# TEETHLOST_AdjPrev.1                                                                                                                                                0.715218
# TEETHLOST_AdjPrev                                                                                                                                                  0.715218
# OBESITY_CrudePrev                                                                                                                                                  0.711512
# LPA_AdjPrev                                                                                                                                                        0.696998
# BPHIGH_AdjPrev                                                                                                                                                     0.694564
# CSMOKING_CrudePrev                                                                                                                                                 0.680278
# CSMOKING_AdjPrev                                                                                                                                                   0.667897
# CSMOKING_AdjPrev.1                                                                                                                                                 0.667897
# LPA_CrudePrev                                                                                                                                                      0.662622
# PHLTH_CrudePrev                                                                                                                                                    0.661048
# Percent; OCCUPATION - Civilian employed population 16 years and over - Service occupations                                                                         0.641906
# ARTHRITIS_AdjPrev                                                                                                                                                  0.628181
# CASTHMA_CrudePrev                                                                                                                                                  0.622359
# STROKE_CrudePrev                                                                                                                                                   0.613989
#                                                                                                                                                                      ...
# Estimate; CLASS OF WORKER - Civilian employed population 16 years and over - Private wage and salary workers                                                       0.057674
# Estimate; CLASS OF WORKER - Civilian employed population 16 years and over - Self-employed in own not incorporated business workers                                0.035168
# Estimate; CLASS OF WORKER - Civilian employed population 16 years and over - Unpaid family workers                                                                 0.027482
# Estimate; OCCUPATION - Civilian employed population 16 years and over - Management, business, science, and arts occupations                                        0.017334
# Percent; OCCUPATION - Civilian employed population 16 years and over - Sales and office occupations                                                               -0.066880
# Percent; CLASS OF WORKER - Civilian employed population 16 years and over - Unpaid family workers                                                                 -0.084865
# Percent; CLASS OF WORKER - Civilian employed population 16 years and over - Private wage and salary workers                                                       -0.130252
# CANCER_AdjPrev                                                                                                                                                    -0.163287
# Percent; CLASS OF WORKER - Civilian employed population 16 years and over - Self-employed in own not incorporated business workers                                -0.195919
# COREM_CrudePrev                                                                                                                                                   -0.237794
# BINGE_CrudePrev                                                                                                                                                   -0.244162
# COREM_AdjPrev                                                                                                                                                     -0.247064
# CANCER_CrudePrev                                                                                                                                                  -0.273070
# MAMMOUSE_CrudePrev                                                                                                                                                -0.302000
# MAMMOUSE_AdjPrev                                                                                                                                                  -0.325538
# CHOLSCREEN_AdjPrev                                                                                                                                                -0.365139
# BINGE_AdjPrev                                                                                                                                                     -0.387100
# COREW_AdjPrev                                                                                                                                                     -0.417995
# COREW_CrudePrev                                                                                                                                                   -0.426684
# Percent; OCCUPATION - Civilian employed population 16 years and over - Management, business, science, and arts occupations                                        -0.479240
# COLON_SCREEN_CrudePrev                                                                                                                                            -0.508651
# PAPTEST_AdjPrev                                                                                                                                                   -0.510674
# COLON_SCREEN_AdjPrev                                                                                                                                              -0.537122
# CHOLSCREEN_CrudePrev                                                                                                                                              -0.543219
# PAPTEST_CrudePrev                                                                                                                                                 -0.589406
# Estimate; INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) - Per capita income (dollars)                                                                  -0.651488
# DENTAL_AdjPrev.1                                                                                                                                                  -0.701787
# DENTAL_AdjPrev                                                                                                                                                    -0.701787
# DENTAL_CrudePrev                                                                                                                                                  -0.711764
# % of Pop 15+ Now Married                                                                                                                                          -0.792834
# Name: Percent; PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL - All people, Length: 99, dtype: float64

# %%
corr_matrix2 = df1.corr()
corr_matrix2['All People Under PL(%)'].sort_values(ascending=False)
# Out:
# All People Under PL(%)           1.000000
# Female household under PL (%)    0.800453
# %onFoodStamps                    0.776293
# OBESITY_AdjPrev                  0.724492
# DIABETES_AdjPrev                 0.722793
# % of pop 15+ not married         0.718928
# Per Capita Income (2016)        -0.651488
# DENTAL_AdjPrev                  -0.701787
# % of Pop 15+ Now Married        -0.792834
# Name: All People Under PL(%), dtype: float64

# %%
attributes = [
    'Per Capita Income (2016)',
    '%onFoodStamps',
    'DIABETES_AdjPrev',
    '% of pop 15+ not married',
    'All People Under PL(%)'
]

scatter_matrix(df1[attributes], figsize=(30, 30))
# Out:
# /Users/jayklein95/anaconda/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:9: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11083e470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c2172e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1101b7cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c19ee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c403080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c4030b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c54b438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c55c940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c60eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c662c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c687898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c73e2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c7b76a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c819550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c852d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c8e09b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8efe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c9933c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c99dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca58e48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11caafc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cb25908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cb882e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cc025c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cc64550>]],
#       dtype=object)

# %%
df1.shape
# Out:
# (488, 11)

# %%
df1.describe()
# Out:
#        Per Capita Income (2016)  All People Under PL(%)  \
# count                488.000000              488.000000
# mean               30134.411885               16.054508
# std                 9834.990940                7.316350
# min                13652.000000                2.700000
# 25%                23389.000000               10.500000
# 50%                27794.500000               15.500000
# 75%                34423.250000               20.400000
# max                85801.000000               44.500000
#
#        Female household under PL (%)  %onFoodStamps  DIABETES_AdjPrev  \
# count                     488.000000     488.000000        488.000000
# mean                       26.460451      13.851434         10.289754
# std                        10.808012       8.329978          2.374829
# min                         2.100000       0.900000          5.400000
# 25%                        18.200000       7.600000          8.475000
# 50%                        27.100000      12.900000         10.100000
# 75%                        33.525000      18.200000         11.700000
# max                        63.900000      47.900000         18.200000
#
#        OBESITY_AdjPrev  DENTAL_AdjPrev  % of pop 15+ not married  \
# count       488.000000      488.000000                488.000000
# mean         29.085246       62.169262                 38.303279
# std           5.755421        7.458220                  8.181947
# min          15.200000       38.800000                 20.000000
# 25%          25.075000       56.700000                 32.600000
# 50%          29.150000       62.100000                 37.100000
# 75%          33.100000       67.500000                 43.600000
# max          47.200000       79.700000                 62.800000
#
#        % of Pop 15+ Now Married
# count                488.000000
# mean                  45.422951
# std                    8.420607
# min                   23.400000
# 25%                   39.675000
# 50%                   45.800000
# 75%                   51.025000
# max                   67.300000

# %%
corr_matrix = df1.corr()
corr_matrix['All People Under PL(%)'].sort_values(ascending=False)
# Out:
# All People Under PL(%)           1.000000
# Female household under PL (%)    0.800453
# %onFoodStamps                    0.776293
# OBESITY_AdjPrev                  0.724492
# DIABETES_AdjPrev                 0.722793
# % of pop 15+ not married         0.718928
# Per Capita Income (2016)        -0.651488
# DENTAL_AdjPrev                  -0.701787
# % of Pop 15+ Now Married        -0.792834
# Name: All People Under PL(%), dtype: float64

# %% [markdown]
# Multivariate Linear Regression
# ==============

# %%
X1 = df1[[
    "Female household under PL (%)",
    "%onFoodStamps",
    "OBESITY_AdjPrev",
    "DIABETES_AdjPrev",
    "% of pop 15+ not married",
    "Per Capita Income (2016)",
    "DENTAL_AdjPrev",
    "% of Pop 15+ Now Married"
]]

y1 = df1['All People Under PL(%)']

# %%
y1 = y1.values.reshape(-1, 1)

print(y1.shape, X1.shape)
# Out:
# (488, 1) (488, 8)

# %%
mlr = LinearRegression()
mlr.fit(X1, y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
score = mlr.score(X1, y1)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.862915373193716

# %% [markdown]
# residuals

# %%
predictions = mlr.predict(X1)
# Plot Residuals
plt.scatter(predictions, predictions - y1)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

# %% [markdown]
# POV vs. Households Under PL led by Female (no male authority figure, %)
# ===============

# %%
X2 = df1["Female household under PL (%)"].values.reshape(-1, 1)
y2 = df1['All People Under PL(%)'].values.reshape(-1, 1)
print("Shape: ", X2.shape, y2.shape)
# Out:
# Shape:  (488, 1) (488, 1)

# %%
plt.scatter(X2, y2)
plt.xlabel("Single-Parent Household under Poverty Line (%, Female)")
plt.ylabel("All People Under PL (%)")

# %%
lr2_ = LinearRegression()
lr2_.fit(X2, y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = lr2_.predict(X2)
print(f"True output: {y2[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y2[0]}")
# Out:
# True output: [24.5]
# Predicted output: [20.95265091]
# Prediction Error: [-3.54734909]

# %%
x2_min = np.array([[X2.min()]])
x2_max = np.array([[X2.max()]])
y2_min = lr2_.predict(x2_min)
y2_max = lr2_.predict(x2_max)

# %%
plt.scatter(X2, y2, c='blue')
plt.plot([x2_min[0], x2_max[0]], [y2_min[0], y2_max[0]], c='red')
plt.title("Poverty Level of a City vs. Poverty level of Single Parent (Female) Households")
plt.xlabel("Female household under PL (%)")
plt.ylabel("All People Under PL(%)")

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, random_state=42)
lr2 = LinearRegression()

# %%
lr2.fit(X2_train, y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predicted = lr2.predict(X2_test)

# Score the predictions with mse and r2
mse2 = mean_squared_error(y2_test, predicted)
r22 = r2_score(y2_test, predicted)

print(f"Mean Squared Error (MSE): {mse2}")
print(f"R-squared (R2 ): {r22}")
# Out:
# Mean Squared Error (MSE): 17.200311767350943
# R-squared (R2 ): 0.6557456906123491

# %% [markdown]
# POV v. Obesity
# =============

# %%
X3 = df1["OBESITY_AdjPrev"].values.reshape(-1, 1)
y3 = df1['All People Under PL(%)'].values.reshape(-1, 1)
print("Shape: ", X3.shape, y3.shape)
# Out:
# Shape:  (488, 1) (488, 1)

# %%
plt.scatter(X3, y3)
plt.xlabel("Obesity (%)")
plt.ylabel("All People Under PL (%)")

# %%
lr3_ = LinearRegression()
lr3_.fit(X3, y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = lr3_.predict(X3)
print(f"True output: {y3[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y3[0]}")
# Out:
# True output: [24.5]
# Predicted output: [25.18581355]
# Prediction Error: [0.68581355]

# %%
x3_min = np.array([[X3.min()]])
x3_max = np.array([[X3.max()]])
y3_min = lr3_.predict(x3_min)
y3_max = lr3_.predict(x3_max)

# %%
plt.scatter(X3, y3, c='blue')
plt.plot([x3_min[0], x3_max[0]], [y3_min[0], y3_max[0]], c='red')
plt.xlabel("Obesity (%)")
plt.ylabel("People Under Poverty Line (%)")
plt.title("Poverty vs. Obesity")

# %% [markdown]
# POV vs. % of Pop 15 or over Now Married
# ===================

# %%
X4 = df1["% of Pop 15+ Now Married"].values.reshape(-1, 1)
y4 = df1['All People Under PL(%)'].values.reshape(-1, 1)
print("Shape: ", X4.shape, y4.shape)
# Out:
# Shape:  (488, 1) (488, 1)

# %%
plt.scatter(X4, y4)
plt.xlabel("% of Pop 15+ who are Now Married")
plt.ylabel("All People Under PL (%)")

# %%
lr4_ = LinearRegression()
lr4_.fit(X4, y4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = lr4_.predict(X4)
print(f"True output: {y4[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y4[0]}")
# Out:
# True output: [24.5]
# Predicted output: [24.26779892]
# Prediction Error: [-0.23220108]

# %%
x4_min = np.array([[X4.min()]])
x4_max = np.array([[X4.max()]])
y4_min = lr4_.predict(x4_min)
y4_max = lr4_.predict(x4_max)

# %%
plt.scatter(X4, y4, c='blue')
plt.plot([x4_min[0], x4_max[0]], [y4_min[0], y4_max[0]], c='red')
plt.xlabel("% of Pop 15+ Now Married")
plt.ylabel("All People Under PL(%)")
plt.title("Poverty Levels vs. % of People Now Married")

# %% [markdown]
# Food Stamps vs. Obesity
# ===============

# %%
y5 = df1["%onFoodStamps"].values.reshape(-1, 1)
X5 = df1["OBESITY_AdjPrev"].values.reshape(-1, 1)
print(X5.shape, y5.shape)
# Out:
# (488, 1) (488, 1)

# %%
plt.scatter(X3, y3)
plt.xlabel("Obesity (%)")
plt.ylabel("% of People on Foodstamps")

# %%
lr5 = LinearRegression()
lr5.fit(X5, y5)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = lr5.predict(X5)
print(f"True output: {y5[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y5[0]}")
# Out:
# True output: [25.4]
# Predicted output: [24.43094725]
# Prediction Error: [-0.96905275]

# %%
x5_min = np.array([[X5.min()]])
x5_max = np.array([[X5.max()]])
y5_min = lr5.predict(x5_min)
y5_max = lr5.predict(x5_max)

# %%
plt.scatter(X5, y5, c='blue')
plt.plot([x5_min[0], x5_max[0]], [y5_min[0], y5_max[0]], c='red')
plt.ylabel("% of people on foodstamps")
plt.xlabel("% of people considered obese")
plt.title("Obesity vs. Foodstamps")
